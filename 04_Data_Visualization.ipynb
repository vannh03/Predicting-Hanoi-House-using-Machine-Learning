# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./hanoi_house_processing_1.csv')

# %%
df
# Out:
#       price  location  size  Price_per_m2  bedroom  toi_list  mat_tien  floor  \
# 0      7.30         5  60.0        121.67      3.0       4.0  5.000000    5.0
# 1      4.50         5  35.0        128.57      3.0       4.0  4.000000    5.0
# 2      8.65        19  46.0        188.04      4.0       4.0  4.504429    4.0
# 3      4.85        16  46.0        105.44      4.0       3.0  4.700000    5.0
# 4      4.50        16  36.0        125.00      4.0       4.0  4.504429    5.0
# ...     ...       ...   ...           ...      ...       ...       ...    ...
# 2358   5.15        10  78.0         66.03      3.0       3.0  4.500000    2.0
# 2359   9.00         8  68.0        132.35      3.0       2.0  5.000000    5.0
# 2360   3.50        16  30.0        116.67      4.0       6.0  4.504429    5.0
# 2361   5.68        10  50.0        113.60      3.0       3.0  5.000000    5.0
# 2362  12.70         8  63.0        201.59      4.0       4.0  4.500000    4.0
#
#       duong_vao  phap_ly  noi_that  Huong  Huong_ban_cong
# 0           4.9        2         1      8               6
# 1           4.9        2         3      8               6
# 2           4.9        2         3      8               6
# 3           4.9        2         4      8               6
# 4          10.0        2         4      8               6
# ...         ...      ...       ...    ...             ...
# 2358        4.5        2         4      8               6
# 2359        8.0        2         4      8               6
# 2360        4.9        2         3      8               6
# 2361        4.9        2         4      8               6
# 2362        5.0        2         3      8               6
#
# [2363 rows x 13 columns]

# %%
df.describe()
# Out:
#              price     location         size  Price_per_m2      bedroom  \
# count  2363.000000  2363.000000  2363.000000   2363.000000  2363.000000
# mean      5.716297    10.194668    45.591363    122.209661     3.416480
# std       3.798160     5.244587    18.159600     53.468510     0.635752
# min       1.050000     0.000000    15.000000     22.900000     1.000000
# 25%       3.350000     8.000000    35.000000     88.750000     3.000000
# 50%       4.500000    10.000000    40.000000    110.000000     3.416480
# 75%       6.600000    15.000000    51.000000    142.860000     4.000000
# max      28.000000    19.000000   173.000000    407.690000     5.000000
#
#           toi_list     mat_tien        floor    duong_vao      phap_ly  \
# count  2363.000000  2363.000000  2363.000000  2363.000000  2363.000000
# mean      3.611562     4.504429     4.461714     4.553978     2.190013
# std       0.857910     0.910905     1.027415     1.723843     0.401987
# min       1.000000     2.000000     1.000000     1.000000     1.000000
# 25%       3.000000     4.000000     4.000000     3.000000     2.000000
# 50%       3.611562     4.504429     4.461714     4.900000     2.000000
# 75%       4.000000     4.504429     5.000000     4.900000     2.000000
# max       9.000000    14.000000     9.000000    17.000000     3.000000
#
#           noi_that        Huong  Huong_ban_cong
# count  2363.000000  2363.000000     2363.000000
# mean      3.009733     7.460432        5.995768
# std       1.071290     1.551958        0.082195
# min       0.000000     0.000000        4.000000
# 25%       3.000000     8.000000        6.000000
# 50%       3.000000     8.000000        6.000000
# 75%       4.000000     8.000000        6.000000
# max       4.000000     8.000000        6.000000

# %%
var = 'location'
data = pd.concat([df['price'], df[var]], axis=1)
data.plot.scatter(x=var, y='price')
# Out:
# <Axes: xlabel='location', ylabel='price'>

# %%
var = 'size'
data = pd.concat([df['price'], df[var]], axis=1)
data.plot.scatter(x=var, y='price')
# Out:
# <Axes: xlabel='size', ylabel='price'>

# %%
var = 'Price_per_m2'
data = pd.concat([df['price'], df[var]], axis=1)
data.plot.scatter(x=var, y='price')
# Out:
# <Axes: xlabel='Price_per_m2', ylabel='price'>

# %%
# bedroom
var = 'bedroom'
data = pd.concat([df['price'], df[var]], axis=1)
data.plot.scatter(x=var, y='price')
# Out:
# <Axes: xlabel='bedroom', ylabel='price'>

# %%
# toi_list
var = 'toi_list'
data = pd.concat([df['price'], df[var]], axis=1)
data.plot.scatter(x=var, y='price')
# Out:
# <Axes: xlabel='toi_list', ylabel='price'>

# %%
# mat_tien
var = 'mat_tien'
data = pd.concat([df['price'], df[var]], axis=1)
data.plot.scatter(x=var, y='price')
# Out:
# <Axes: xlabel='mat_tien', ylabel='price'>

# %%
# floor
var = 'floor'
data = pd.concat([df['price'], df[var]], axis=1)
data.plot.scatter(x=var, y='price')
# Out:
# <Axes: xlabel='floor', ylabel='price'>

# %%
# duong_vao	
var = 'duong_vao'
data = pd.concat([df['price'], df[var]], axis=1)
data.plot.scatter(x=var, y='price')
# Out:
# <Axes: xlabel='duong_vao', ylabel='price'>

# %%
def plot_correlation_heatmap(df: pd.core.frame.DataFrame, title_name: str='Train correlation') -> None:

    corr = df.corr()
    fig, axes = plt.subplots(figsize=(12, 8))
    mask = np.zeros_like(corr)
    mask[np.triu_indices_from(mask)] = True
    sns.heatmap(corr, mask=mask, linewidths=.5, cmap='RdBu_r', annot=True,annot_kws={"size": 8})
    plt.title(title_name)
    plt.show()

# %%
plot_correlation_heatmap(df)

# %%
plt.figure(figsize=(10, 7))
plt.bar(df['location'], df['price'])
plt.xlabel('Location')
plt.ylabel('Price')
plt.title('Price by Location')
# plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# 3 nơi có mức giá nhà cao nhất :
avg_price_by_location = df.groupby('location')['price'].mean()

# Plot the data
avg_price_by_location.plot(kind='bar')
plt.title('Average Price by Location')
plt.xlabel('Location')
plt.ylabel('Average Price')
plt.show()

# %%
df1 = pd.read_csv('./hanoi_house_final_4.csv')

# %%
df1.head(50)
# Out:
#     price              location   size  Price_per_m2  bedroom  toi_list  \
# 0    7.30  Hai Bà Trưng, Hà Nội   60.0        121.67      3.0       4.0
# 1    4.50  Hai Bà Trưng, Hà Nội   35.0        128.57      3.0       4.0
# 2    8.65       Đống Đa, Hà Nội   46.0        188.04      4.0       4.0
# 3    4.85    Thanh Xuân, Hà Nội   46.0        105.44      4.0       3.0
# 4    4.50    Thanh Xuân, Hà Nội   36.0        125.00      4.0       4.0
# 5    7.00  Hai Bà Trưng, Hà Nội   35.0        200.00      3.0       4.0
# 42   7.60       Đống Đa, Hà Nội   60.0        126.67      4.0       3.0
# 43   3.25     Long Biên, Hà Nội   33.0         98.48      4.0       3.0
# 44   7.60       Hà Đông, Hà Nội   50.0        152.00      4.0       4.0
# 45  20.00    Thanh Xuân, Hà Nội  120.0        166.67      4.0       2.0
# 46   7.60   Nam Từ Liêm, Hà Nội   54.0        126.22      4.0       NaN
# 47   5.68       Hà Đông, Hà Nội   45.0         92.50      3.0       4.0
# 48   1.48    Thanh Xuân, Hà Nội   16.0         82.33      4.0       4.0
# 49   1.77     Thanh Trì, Hà Nội   21.5        147.37      3.0       2.0
#
#     mat_tien  floor  duong_vao         phap_ly        noi_that       Huong  \
# 0       5.00    5.0        4.9  Sổ đỏ/ Sổ hồng          Cơ bản         NaN
# 1       4.00    5.0        4.9  Sổ đỏ/ Sổ hồng          Đầy đủ         NaN
# 2        NaN    4.0        4.9  Sổ đỏ/ Sổ hồng          Đầy đủ         NaN
# 3       4.70    5.0        4.9  Sổ đỏ/ Sổ hồng             NaN         NaN
# 4        NaN    5.0       10.0  Sổ đỏ/ Sổ hồng             NaN         NaN
# 5        NaN    6.0        4.9  Sổ đỏ/ Sổ hồng          Đầy đủ         NaN
# 6       4.00    5.0        5.0  Sổ đỏ/ Sổ hồng          Đầy đủ         NaN
# 7       3.00    4.0        3.0  Sổ đỏ/ Sổ hồng          Cơ bản         NaN
# 8        NaN    5.0        4.9  Sổ đỏ/ Sổ hồng          Cơ bản         NaN
# 9        NaN    4.0        4.9  Sổ đỏ/ Sổ hồng          Đầy đủ         NaN
# 10       NaN    5.0        4.9  Sổ đỏ/ Sổ hồng          Cơ bản         NaN
# 11      3.90    4.0        2.2  Sổ đỏ/ Sổ hồng  Không nội thất   Tây - Nam
# 12       NaN    6.0        4.9  Sổ đỏ/ Sổ hồng             NaN         NaN
# 13       NaN    NaN        4.9  Sổ đỏ/ Sổ hồng         Cao cấp         NaN
# 14       NaN    NaN        4.9  Sổ đỏ/ Sổ hồng          Đầy đủ         NaN
# 15       NaN    5.0        4.9  Sổ đỏ/ Sổ hồng          Đầy đủ         NaN
# 16      7.00    4.0        4.0  Sổ đỏ/ Sổ hồng         Cao cấp         NaN
# 17       NaN    5.0        4.9  Sổ đỏ/ Sổ hồng          Đầy đủ         NaN
# 18      4.50    6.0        2.0  Sổ đỏ/ Sổ hồng          Đầy đủ         NaN
# 19      5.20    2.0        3.5  Sổ đỏ/ Sổ hồng          Cơ bản   Tây - Bắc
# 20      4.00    5.0        8.0  Sổ đỏ/ Sổ hồng          Đầy đủ         NaN
# 21      4.50    4.0        2.5  Sổ đỏ/ Sổ hồng             NaN  Đông - Nam
# 22      5.00    5.0        2.8  Sổ đỏ/ Sổ hồng             NaN   Tây - Bắc
# 23      5.00    5.0        6.0  Sổ đỏ/ Sổ hồng             NaN   Tây - Nam
# 24      3.70    5.0        3.0  Sổ đỏ/ Sổ hồng          Đầy đủ         NaN
# 25       NaN    3.0        4.9             NaN             NaN         NaN
# 26       NaN    4.0        3.0  Sổ đỏ/ Sổ hồng          Đầy đủ   Tây - Bắc
# 27      6.00    5.0        3.3  Sổ đỏ/ Sổ hồng          Đầy đủ         NaN
# 28       NaN    5.0        4.9  Sổ đỏ/ Sổ hồng          Đầy đủ         NaN
# 29       NaN    6.0        4.9  Sổ đỏ/ Sổ hồng          Đầy đủ         NaN
# 30      9.30    4.0        4.9  Sổ đỏ/ Sổ hồng          Đầy đủ         NaN
# 31       NaN    4.0        4.9  Sổ đỏ/ Sổ hồng             NaN         NaN
# 32      3.60    5.0        4.0  Sổ đỏ/ Sổ hồng          Đầy đủ         NaN
# 33      6.00    5.0        3.0  Sổ đỏ/ Sổ hồng             NaN   Tây - Bắc
# 34      5.00    5.0        2.8  Sổ đỏ/ Sổ hồng             NaN   Tây - Bắc
# 35       NaN    5.0        4.9  Sổ đỏ/ Sổ hồng          Đầy đủ         NaN
# 36       NaN    7.0        4.9  Sổ đỏ/ Sổ hồng          Đầy đủ         NaN
# 37       NaN    4.0        4.9  Sổ đỏ/ Sổ hồng          Cơ bản         NaN
# 38      6.00    5.0        4.9  Sổ đỏ/ Sổ hồng          Cơ bản         NaN
# 39      5.50    9.0       10.0  Sổ đỏ/ Sổ hồng          Đầy đủ         Bắc
# 40      4.00    5.0        3.0  Sổ đỏ/ Sổ hồng          Đầy đủ         NaN
# 41      5.75    5.0        7.0  Sổ đỏ/ Sổ hồng          Đầy đủ         NaN
# 42       NaN    4.0        2.0  Sổ đỏ/ Sổ hồng          Đầy đủ   Tây - Nam
# 43      3.80    5.0        4.9  Sổ đỏ/ Sổ hồng             NaN         NaN
# 44      4.00    4.0        6.0  Sổ đỏ/ Sổ hồng          Đầy đủ         NaN
# 45      8.00    4.0        8.0  Sổ đỏ/ Sổ hồng  Không nội thất  Đông - Bắc
# 46      3.90    4.0        4.5  Sổ đỏ/ Sổ hồng          Đầy đủ         NaN
# 47      4.00    5.0       16.0  Sổ đỏ/ Sổ hồng          Đầy đủ         NaN
# 48      3.00    3.0        2.0  Sổ đỏ/ Sổ hồng          Cơ bản         NaN
# 49      3.20    5.0        4.9             NaN             NaN         NaN
#
#    Huong_ban_cong
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN
# 23            NaN
# 24            NaN
# 25            NaN
# 26            NaN
# 27            NaN
# 28            NaN
# 29            NaN
# 30            NaN
# 31            NaN
# 32            NaN
# 33            NaN
# 34            NaN
# 35            NaN
# 36            NaN
# 37            NaN
# 38            NaN
# 39            NaN
# 40            NaN
# 41            NaN
# 42            NaN
# 43            NaN
# 44            NaN
# 45            NaN
# 46            NaN
# 47            NaN
# 48            NaN
# 49            NaN
